# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pd.read_csv('../data/states_edu.csv')
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
df.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_EST'
    },
    axis=1,inplace=True)
df.dropna(subset=['AVG_MATH_4_SCORE'], inplace=True)
df["ENROLL_ALL"].isna().sum() #different from tutorial where sum = 75, because subset has changed
# Out:
# 74

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: *AVG_MATH_4_SCORE*

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
#df.groupby("YEAR").count()
df.YEAR.nunique()
# Out:
# 13

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
#df["MICHIGAN"]["GRADES_ALL_G"] > df["OHIO"]["GRADES_ALL_G"]
#state_MI = df.loc[df[df['STATE'] == 'MICHIGAN'] == 'AVG_MATH_4_SCORE']]
state_MI = df.loc[df['STATE'] == 'MICHIGAN']
avg_MI = state_MI['AVG_MATH_4_SCORE'].sum()

state_OH = df.loc[df['STATE'] == 'OHIO']
avg_OH = state_OH['AVG_MATH_4_SCORE'].sum()

if (avg_MI > avg_OH) : print("Michigan")
else : print("OHIO")
# Out:
# OHIO

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
y2019 = df.loc[df['YEAR'] == 2019]
avg2019 = y2019['AVG_MATH_4_SCORE'].sum()
states2019 = y2019['STATE'].count()
totalAvg = avg2019/states2019; roundedAvg = round(totalAvg, 3)
print(roundedAvg)
# Out:
# 239.943

# %% [markdown]
# Find the maximum outcome score for every state.
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
#groupState = df.groupby('STATE')
df.groupby(["STATE"])["AVG_MATH_4_SCORE"].max()
# Out:
# STATE
# ALABAMA                 233.0
# ALASKA                  237.0
# ARIZONA                 240.0
# ARKANSAS                240.0
# CALIFORNIA              235.0
# COLORADO                247.0
# CONNECTICUT             245.0
# DELAWARE                243.0
# DISTRICT_OF_COLUMBIA    235.0
# DODEA                   250.0
# FLORIDA                 246.0
# GEORGIA                 240.0
# HAWAII                  243.0
# IDAHO                   242.0
# ILLINOIS                239.0
# INDIANA                 249.0
# IOWA                    246.0
# KANSAS                  248.0
# KENTUCKY                242.0
# LOUISIANA               234.0
# MAINE                   246.0
# MARYLAND                247.0
# MASSACHUSETTS           253.0
# MICHIGAN                238.0
# MINNESOTA               253.0
# MISSISSIPPI             241.0
# MISSOURI                241.0
# MONTANA                 244.0
# NATIONAL                242.0
# NEBRASKA                246.0
# NEVADA                  237.0
# ...

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
df['State_VS_Avg_Math_4_Score'] = df['TOTAL_EXPENDITURE'] / df['AVG_MATH_4_SCORE']

# %% [markdown]
# Feature engineering justification: **<Added a new column that shows the total expenditure for each average math score in 4th grade. Technically just a BS column cause the money isn't only being used for 4th grade math curriculum and dividing the total expenditure by the avg math 4 score doesn't really tell us anything useful\>**

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
df.groupby('YEAR')["AVG_MATH_4_SCORE"].mean().plot()
plt.ylabel('SCORE')
plt.title('4th Grade Math Score Over Time')
# Out:
# Text(0.5, 1.0, '4th Grade Math Score Over Time')

# %% [markdown]
# **<In this graph, we can see there exists a fairly strong correlation between our independent variable time (years 1990-2020) and our response variable score (Avg 4th grade math scores) and that it has been increasing over time. Although there may be several other factors that affect score, at least this graph lets us know that there is a strong, positive correlation between time passes and average math scores of 4th graders.>**

# %% [markdown]
# **Visualization 2**

# %%
df.plot.scatter(x='INSTRUCTION_EXPENDITURE', y='AVG_MATH_4_SCORE', alpha=0.6)
plt.xlabel('Instruction Expenditure')
plt.ylabel('4th Grade Math Score')
# Out:
# Text(0, 0.5, '4th Grade Math Score')

# %% [markdown]
# **<The scatterplot above shows that there doesn't seem to be much of a correlation between instruction expenditure and avg 4th grade math scores. The average math scores for 4th graders are generally higher when the instruction expenditure is higher, but it's hard to suggest whether there is a strong correlation because of the lack of enough data points. For the scores below 1 million in instruction expenditure however, we can see that the scores are split throughout, though a lot of the data points are saturated between 230 and 250.  2>**

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['ENROLL_4','AVG_READING_4_SCORE','AVG_MATH_8_SCORE']].dropna()
y = df.loc[X.index]['AVG_MATH_4_SCORE']

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#      X, y, test_size=, random_state=42)
y.fillna(y.mean(), inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=0)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
# import your sklearn class here
from sklearn.linear_model import LinearRegression

# %%
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
#print(model.intercept_)
#print(model.coef_)
print(model.score(X_test, y_test), "= R^2 value") #R^2 value
print(np.mean(model.predict(X_test)-y_test), "= Mean Error")
print(np.mean((model.predict(X_test)-y_test)**2)**0.5, "= Root Mean Squared Error")
# Out:
# 0.8592428654354612 = R^2 value
# 0.08021777051295516 = Mean Error
# 3.5094786544530177 = Root Mean Squared Error

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_READING_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Math 4 Score')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
col_name = 'AVG_READING_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_test[col_name], y_test, color = "blue")
plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

plt.legend(['True testing','Predicted testing'])
plt.xlabel(col_name)
plt.ylabel('Math 4 Score')
plt.title("Model Behavior on Testing Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior on Testing Set')

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# **<Since the tutorial used a testing set of size 0.3% of the total data, I tried using a testing set of size 0.4% to see the different in the precision of the testing set. Visually, there's not much of a difference between the Model Behavior on the Testing Set between my graph and the tutorial's graph. However, there is a larger difference in the Model Behavior on the Training Set compared to the tutorial. This is because there is a greater disparity in the average 4th grade math adn reading scores and the correlation between the two isn't as strong which surprises me because the predicted testing points are still quite similar to the true testing on the testing set. Decreasing the amount of training data, I would have expected the accuracy of the model to decrease. However, it seems that removing 10% of the training data compared to the tutorial made no big visible difference. Furthermore, the R^2 value being 0.859 probably also contributed to why the predicted model did so well because the training data between 4th grade reading and math scores follow a positive, upwards trend and predicting points for a close to linear data set isn't too difficult. It would be interesting, however, to see how good the model works on data sets that have smaller R^2 values. \>**
